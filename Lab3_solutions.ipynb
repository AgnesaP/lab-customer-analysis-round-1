# %%
import pandas as pd
import numpy as np

# %%
file1=pd.read_excel('files_for_lab/excel_files/file1.xlsx')
file1
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 1066  TM65736      Oregon      M                Master
# 1067  VJ51327        Cali      F  High School or Below
# 1068  GS98873     Arizona      F              Bachelor
# 1069  CW49887  California      F                Master
# 1070  MY31220  California      F               College
#
#      Customer Lifetime Value  Income  Monthly Premium Auto  \
# 0                        NaN       0                  1000
# 1                 697953.59%       0                    94
# 2                1288743.17%   48767                   108
# 3                 764586.18%       0                   106
# ...

# %%
file2=pd.read_excel('files_for_lab/excel_files/file2.xlsx')
file2
# Out:
#     Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# ...

# %%
file3=pd.read_excel('files_for_lab/excel_files/file3.xlsx')
file3
# Out:
#      Customer       State  Customer Lifetime Value             Education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      Gender  Income  Monthly Premium Auto  Number of Open Complaints  \
# ...

# %%
print(file1.shape)
# Out:
# (1071, 11)

# %%
print(file2.shape)
# Out:
# (996, 11)

# %%
print(file3.shape)
# Out:
# (7070, 11)

# %%
file1.head()
# Out:
#   Customer          ST GENDER             Education Customer Lifetime Value  \
# 0  RB50392  Washington    NaN                Master                     NaN
# 1  QZ44356     Arizona      F              Bachelor              697953.59%
# 2  AI49188      Nevada      F              Bachelor             1288743.17%
# 3  WW63253  California      M              Bachelor              764586.18%
# 4  GA49547  Washington      M  High School or Below              536307.65%
#
#    Income  Monthly Premium Auto Number of Open Complaints     Policy Type  \
# 0       0                  1000                    1/0/00   Personal Auto
# 1       0                    94                    1/0/00   Personal Auto
# 2   48767                   108                    1/0/00   Personal Auto
# 3       0                   106                    1/0/00  Corporate Auto
# 4   36357                    68                    1/0/00   Personal Auto
#
#    Vehicle Class  Total Claim Amount
# ...

# %%
file2.head()
# Out:
#   Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0  GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1  CW49887  California      F    Master              462680.11%   79487
# 2  MY31220  California      F   College              899704.02%   54230
# 3  UH35128      Oregon      F   College             2580706.30%   71210
# 4  WH52799     Arizona      F   College              380812.21%   94903
#
#    Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# 0                    88                    1/0/00               633.6
# 1                   114                    1/0/00               547.2
# 2                   112                    1/0/00               537.6
# 3                   214                    1/1/00              1027.2
# 4                    94                    1/0/00               451.2
#
#       Policy Type  Vehicle Class
# 0   Personal Auto  Four-Door Car
# 1    Special Auto            SUV
# ...

# %%
file3.head()
# Out:
#   Customer       State  Customer Lifetime Value             Education Gender  \
# 0  SA25987  Washington              3479.137523  High School or Below      M
# 1  TB86706     Arizona              2502.637401                Master      M
# 2  ZL73902      Nevada              3265.156348              Bachelor      F
# 3  KX23516  California              4455.843406  High School or Below      F
# 4  FN77294  California              7704.958480  High School or Below      M
#
#    Income  Monthly Premium Auto  Number of Open Complaints    Policy Type  \
# 0       0                   104                          0  Personal Auto
# 1       0                    66                          0  Personal Auto
# 2   25820                    82                          0  Personal Auto
# 3       0                   121                          0  Personal Auto
# 4   30366                   101                          2  Personal Auto
#
#    Total Claim Amount  Vehicle Class
# ...

# %%
file1.rename(columns={1: 'State', 2: 'Gender'}, inplace=True)

# %%
file1
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 1066  TM65736      Oregon      M                Master
# 1067  VJ51327        Cali      F  High School or Below
# 1068  GS98873     Arizona      F              Bachelor
# 1069  CW49887  California      F                Master
# 1070  MY31220  California      F               College
#
#      Customer Lifetime Value  Income  Monthly Premium Auto  \
# 0                        NaN       0                  1000
# 1                 697953.59%       0                    94
# 2                1288743.17%   48767                   108
# 3                 764586.18%       0                   106
# ...

# %%
file1.rename(columns = {'ST':'State', 'GENDER':'Gender'}, inplace = True)

# %%
file1
# Out:
#      Customer       State Gender             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 1066  TM65736      Oregon      M                Master
# 1067  VJ51327        Cali      F  High School or Below
# 1068  GS98873     Arizona      F              Bachelor
# 1069  CW49887  California      F                Master
# 1070  MY31220  California      F               College
#
#      Customer Lifetime Value  Income  Monthly Premium Auto  \
# 0                        NaN       0                  1000
# 1                 697953.59%       0                    94
# 2                1288743.17%   48767                   108
# 3                 764586.18%       0                   106
# ...

# %%
file2.rename(columns = {'ST':'State', 'GENDER':'Gender'}, inplace = True)
file2
# Out:
#     Customer       State Gender Education Customer Lifetime Value  Income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# ...

# %%
file3
# Out:
#      Customer       State  Customer Lifetime Value             Education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      Gender  Income  Monthly Premium Auto  Number of Open Complaints  \
# ...

# %%
file1_backup = file1

# %%
file1_new = file1[['Customer', 'State', 'Gender', 'Education','Income','Customer Lifetime Value',
'Policy Type','Number of Open Complaints','Vehicle Class', 'Monthly Premium Auto','Total Claim Amount']]

# %%
file1_new
# Out:
#      Customer       State Gender             Education  Income  \
# 0     RB50392  Washington    NaN                Master       0
# 1     QZ44356     Arizona      F              Bachelor       0
# 2     AI49188      Nevada      F              Bachelor   48767
# 3     WW63253  California      M              Bachelor       0
# 4     GA49547  Washington      M  High School or Below   36357
# ...       ...         ...    ...                   ...     ...
# 1066  TM65736      Oregon      M                Master   38644
# 1067  VJ51327        Cali      F  High School or Below   63209
# 1068  GS98873     Arizona      F              Bachelor   16061
# 1069  CW49887  California      F                Master   79487
# 1070  MY31220  California      F               College   54230
#
#      Customer Lifetime Value     Policy Type Number of Open Complaints  \
# 0                        NaN   Personal Auto                    1/0/00
# ...

# %%
file1 = file1_new

# %%
file1
# Out:
#      Customer       State Gender             Education  Income  \
# 0     RB50392  Washington    NaN                Master       0
# 1     QZ44356     Arizona      F              Bachelor       0
# 2     AI49188      Nevada      F              Bachelor   48767
# 3     WW63253  California      M              Bachelor       0
# 4     GA49547  Washington      M  High School or Below   36357
# ...       ...         ...    ...                   ...     ...
# 1066  TM65736      Oregon      M                Master   38644
# 1067  VJ51327        Cali      F  High School or Below   63209
# 1068  GS98873     Arizona      F              Bachelor   16061
# 1069  CW49887  California      F                Master   79487
# 1070  MY31220  California      F               College   54230
#
#      Customer Lifetime Value     Policy Type Number of Open Complaints  \
# 0                        NaN   Personal Auto                    1/0/00
# ...

# %%
file2_new = file2[['Customer', 'State', 'Gender', 'Education','Income','Customer Lifetime Value',
'Policy Type','Number of Open Complaints','Vehicle Class', 'Monthly Premium Auto','Total Claim Amount']]

# %%
file3_new = file3[['Customer', 'State', 'Gender', 'Education','Income','Customer Lifetime Value',
'Policy Type','Number of Open Complaints','Vehicle Class', 'Monthly Premium Auto','Total Claim Amount']]

# %%
file2 = file2_new

# %%
file3= file3_new

# %%
file3
# Out:
#      Customer       State Gender             Education  Income  \
# 0     SA25987  Washington      M  High School or Below       0
# 1     TB86706     Arizona      M                Master       0
# 2     ZL73902      Nevada      F              Bachelor   25820
# 3     KX23516  California      F  High School or Below       0
# 4     FN77294  California      M  High School or Below   30366
# ...       ...         ...    ...                   ...     ...
# 7065  LA72316  California      M              Bachelor   71941
# 7066  PK87824  California      F               College   21604
# 7067  TD14365  California      M              Bachelor       0
# 7068  UP19263  California      M               College   21941
# 7069  Y167826  California      M               College       0
#
#       Customer Lifetime Value     Policy Type  Number of Open Complaints  \
# 0                 3479.137523   Personal Auto                          0
# ...

# %%
files = pd.concat([file1,file2,file3], ignore_index=True)

# %%
# Out:
#      Customer       State Gender             Education  Income  \
# 0     RB50392  Washington    NaN                Master       0
# 1     QZ44356     Arizona      F              Bachelor       0
# 2     AI49188      Nevada      F              Bachelor   48767
# 3     WW63253  California      M              Bachelor       0
# 4     GA49547  Washington      M  High School or Below   36357
# ...       ...         ...    ...                   ...     ...
# 9132  LA72316  California      M              Bachelor   71941
# 9133  PK87824  California      F               College   21604
# 9134  TD14365  California      M              Bachelor       0
# 9135  UP19263  California      M               College   21941
# 9136  Y167826  California      M               College       0
#
#      Customer Lifetime Value     Policy Type Number of Open Complaints  \
# 0                        NaN   Personal Auto                    1/0/00
# ...

# %%
files.select_dtypes(include=np.number).columns.tolist()
# Out:
# ['Income', 'Monthly Premium Auto', 'Total Claim Amount']

# %%
files.select_dtypes(include=object).columns.tolist()
# Out:
# ['Customer',
#  'State',
#  'Gender',
#  'Education',
#  'Customer Lifetime Value',
#  'Policy Type',
#  'Number of Open Complaints',
#  'Vehicle Class']

# %%
files= files.drop(columns=["Education", "Number of Open Complaints"])

# %%
display(files)
# Out:
#      Customer       State Gender  Income Customer Lifetime Value  \
# 0     RB50392  Washington    NaN       0                     NaN
# 1     QZ44356     Arizona      F       0              697953.59%
# 2     AI49188      Nevada      F   48767             1288743.17%
# 3     WW63253  California      M       0              764586.18%
# 4     GA49547  Washington      M   36357              536307.65%
# ...       ...         ...    ...     ...                     ...
# 9132  LA72316  California      M   71941             23405.98798
# 9133  PK87824  California      F   21604             3096.511217
# 9134  TD14365  California      M       0             8163.890428
# 9135  UP19263  California      M   21941             7524.442436
# 9136  Y167826  California      M       0             2611.836866
#
#          Policy Type  Vehicle Class  Monthly Premium Auto  Total Claim Amount
# 0      Personal Auto  Four-Door Car                  1000            2.704934
# ...

# %%
# Out:
#      Customer       State Gender  Income  \
# 0     RB50392  Washington    NaN       0
# 1     QZ44356     Arizona      F       0
# 2     AI49188      Nevada      F   48767
# 3     WW63253  California      M       0
# 4     GA49547  Washington      M   36357
# ...       ...         ...    ...     ...
# 9132  LA72316  California      M   71941
# 9133  PK87824  California      F   21604
# 9134  TD14365  California      M       0
# 9135  UP19263  California      M   21941
# 9136  Y167826  California      M       0
#
#                                 Customer Lifetime Value     Policy Type  \
# 0                                                   NaN   Personal Auto
# 1     697953.59%697953.59%697953.59%697953.59%697953...   Personal Auto
# 2     1288743.17%1288743.17%1288743.17%1288743.17%12...   Personal Auto
# 3     764586.18%764586.18%764586.18%764586.18%764586...  Corporate Auto
# 4     536307.65%536307.65%536307.65%536307.65%536307...   Personal Auto
# ...

# %%
files
# Out:
#      Customer       State Gender  Income  \
# 0     RB50392  Washington    NaN       0
# 1     QZ44356     Arizona      F       0
# 2     AI49188      Nevada      F   48767
# 3     WW63253  California      M       0
# 4     GA49547  Washington      M   36357
# ...       ...         ...    ...     ...
# 9132  LA72316  California      M   71941
# 9133  PK87824  California      F   21604
# 9134  TD14365  California      M       0
# 9135  UP19263  California      M   21941
# 9136  Y167826  California      M       0
#
#                                 Customer Lifetime Value     Policy Type  \
# 0                                                   NaN   Personal Auto
# 1     697953.59%697953.59%697953.59%697953.59%697953...   Personal Auto
# 2     1288743.17%1288743.17%1288743.17%1288743.17%12...   Personal Auto
# 3     764586.18%764586.18%764586.18%764586.18%764586...  Corporate Auto
# 4     536307.65%536307.65%536307.65%536307.65%536307...   Personal Auto
# ...

# %%
files['Customer Lifetime Value'] = files['Customer Lifetime Value'].replace('%','',regex=True)

# %%
files
# Out:
#      Customer       State Gender  Income Customer Lifetime Value  \
# 0     RB50392  Washington    NaN       0                     NaN
# 1     QZ44356     Arizona      F       0               697953.59
# 2     AI49188      Nevada      F   48767              1288743.17
# 3     WW63253  California      M       0               764586.18
# 4     GA49547  Washington      M   36357               536307.65
# ...       ...         ...    ...     ...                     ...
# 9132  LA72316  California      M   71941             23405.98798
# 9133  PK87824  California      F   21604             3096.511217
# 9134  TD14365  California      M       0             8163.890428
# 9135  UP19263  California      M   21941             7524.442436
# 9136  Y167826  California      M       0             2611.836866
#
#          Policy Type  Vehicle Class  Monthly Premium Auto  Total Claim Amount
# 0      Personal Auto  Four-Door Car                  1000            2.704934
# ...

# %%
files['Customer Lifetime Value'] = pd.to_numeric(files['Customer Lifetime Value'] , errors='coerce')*100

# %%
files = files.fillna(0)

# %%
files['Customer Lifetime Value'] = files['Customer Lifetime Value'].astype(np.int64)

# %%
files
# Out:
#      Customer       State Gender  Income  Customer Lifetime Value  \
# 0     RB50392  Washington      0       0                        0
# 1     QZ44356     Arizona      F       0               6979535900
# 2     AI49188      Nevada      F   48767              12887431700
# 3     WW63253  California      M       0               7645861800
# 4     GA49547  Washington      M   36357               5363076500
# ...       ...         ...    ...     ...                      ...
# 9132  LA72316  California      M   71941                234059879
# 9133  PK87824  California      F   21604                 30965112
# 9134  TD14365  California      M       0                 81638904
# 9135  UP19263  California      M   21941                 75244424
# 9136  Y167826  California      M       0                 26118368
#
#          Policy Type  Vehicle Class  Monthly Premium Auto  Total Claim Amount
# 0      Personal Auto  Four-Door Car                  1000            2.704934
# ...

# %%
files.drop_duplicates()
# Out:
#      Customer       State Gender  Income  Customer Lifetime Value  \
# 0     RB50392  Washington      0       0                        0
# 1     QZ44356     Arizona      F       0                 69795359
# 2     AI49188      Nevada      F   48767                128874317
# 3     WW63253  California      M       0                 76458618
# 4     GA49547  Washington      M   36357                 53630765
# ...       ...         ...    ...     ...                      ...
# 9132  LA72316  California      M   71941                  2340598
# 9133  PK87824  California      F   21604                   309651
# 9134  TD14365  California      M       0                   816389
# 9135  UP19263  California      M   21941                   752444
# 9136  Y167826  California      M       0                   261183
#
#          Policy Type  Vehicle Class  Monthly Premium Auto  Total Claim Amount
# 0      Personal Auto  Four-Door Car                  1000            2.704934
# ...

# %%
files.loc[files['Income'] > 0]
# Out:
#      Customer       State Gender  Income  Customer Lifetime Value  \
# 2     AI49188      Nevada      F   48767                128874317
# 4     GA49547  Washington      M   36357                 53630765
# 5     OC83172      Oregon      F   62902                 82562978
# 6     XZ87318      Oregon      F   55350                 53808986
# 8     DY87989      Oregon      M   14072                241275040
# ...       ...         ...    ...     ...                      ...
# 9130  TF56202  California      M   66367                   503216
# 9131  YM19146  California      F   47761                   410039
# 9132  LA72316  California      M   71941                  2340598
# 9133  PK87824  California      F   21604                   309651
# 9135  UP19263  California      M   21941                   752444
#
#          Policy Type  Vehicle Class  Monthly Premium Auto  Total Claim Amount
# 2      Personal Auto   Two-Door Car                   108          566.472247
# ...
